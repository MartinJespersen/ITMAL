# %% [markdown]
# # ITMAL Exercise
#
# REVISIONS| |
# ---------| |
# 2018-1219| CEF, initial.
# 2018-0214| CEF, major update and put in sync with under/overfitting exe.
# 2018-0220| CEF, fixed revision table malformatting.
# 2018-0225| CEF, minor text updates, and made Qc optional.
# 2018-0225| CEF, updated code, made more functions.
# 2018-0311| CEF, corrected RSME to RMSE.
# 2019-1008| CEF, updated to ITMAL E19.
#
# ## Generalization Error
#
# In this exercise, we need to explain all important overall concepts in training. Let's begin with Figure 5.3 from Deep Learning, Ian Goodfellow, et. al. [DL], that pretty much sums it all up
#
# <img src="https://itundervisning.ase.au.dk/E19_itmal/L07/Figs/dl_generalization_error.png" style="height:500px">
#
# ### Qa On Generalization Error
#
# Write a detailed description of figure 5.3 (above) for your hand-in.
#
# All concepts in the figure must be explained
#
# * training/generalization error,
# * underfit/overfit zone,
# * optimal capacity,
# * generalization gab,
# * and the two axes: x/capacity, y/error.

# %%
#### TODO: Qa...in text

# %% [markdown]
# ### Qb A MSE-Epoch/Error Plot
#
# Next, we look at a SGD model for fitting polynomial, that _polynomial regression_ similar to what Géron describes in [HOML] ("Polynomial Regression" + "Learning Curves").
#
# Review the code below for plotting the RMSE vs. the iteration number or epoch below (three cells, part I/II/III).
#
# Write a short description of the code, and comment on the important points in the generation of the (R)MSE array.
#
# The training phase output lots of lines like
#
# > `epoch= 104, mse_train=1.50, mse_val=2.37` <br>
# > `epoch= 105, mse_train=1.49, mse_val=2.35`
#
# What is an ___epoch___ and what is `mse_train` and `mse_val`?
#
# NOTE: the generalization plot above (figure 5.3 in [DL]) and the plots below have different x-axis, and are not to be compared directly!

# %%
# Run code: Qb(part I)
# NOTE: modified code from [GITHOML], 04_training_linear_models.ipynb

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

np.random.seed(42)

def GenerateData():
    m = 100
    X = 6 * np.random.rand(m, 1) - 3
    y = 2 + X + 0.5 * X**2 + np.random.randn(m, 1)
    return X, y

X, y = GenerateData()
X_train, X_val, y_train, y_val = \
    train_test_split( \
        X[:50], y[:50].ravel(), \
        test_size=0.5, \
        random_state=10)

print("X_train.shape=",X_train.shape)
print("X_val  .shape=",X_val.shape)
print("y_train.shape=",y_train.shape)
print("y_val  .shape=",y_val.shape)

poly_scaler = Pipeline([
        ("poly_features", PolynomialFeatures(degree=90, include_bias=False)),
        ("std_scaler", StandardScaler()),
    ])

X_train_poly_scaled = poly_scaler.fit_transform(X_train)
X_val_poly_scaled   = poly_scaler.transform(X_val)

X_new=np.linspace(-3, 3, 100).reshape(100, 1)
plt.plot(X, y, "b.", label="All X-y Data")
plt.xlabel("$x_1$", fontsize=18, )
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()

print('OK')
# Out:
# X_train.shape= (25, 1)
# X_val  .shape= (25, 1)
# y_train.shape= (25,)
# y_val  .shape= (25,)
# OK

# %%
# Run code: Qb(part II)

def Train(X_train, y_train, X_val, y_val, n_epochs, verbose=False):
    print("Training...n_epochs=",n_epochs)
    train_errors, val_errors = [], []
    
    sgd_reg = SGDRegressor(max_iter=1,
                           penalty=None,
                           eta0=0.0005,
                           warm_start=True,
                           learning_rate="constant",
                           tol=-float("inf"),
                           random_state=42)

    for epoch in range(n_epochs):
        sgd_reg.fit(X_train, y_train)
        y_train_predict = sgd_reg.predict(X_train)
        y_val_predict   = sgd_reg.predict(X_val)

        mse_train=mean_squared_error(y_train, y_train_predict)
        mse_val  =mean_squared_error(y_val  , y_val_predict)

        train_errors.append(mse_train)
        val_errors  .append(mse_val)
        if verbose:
            print(f"  epoch={epoch:4d}, mse_train={mse_train:4.2f}, mse_val={mse_val:4.2f}")

    return train_errors, val_errors

n_epochs = 500
train_errors, val_errors = Train(X_train_poly_scaled, y_train, X_val_poly_scaled, y_val, n_epochs, True)

print('OK')
# Out:
# 3
#   epoch=  35, mse_train=6.85, mse_val=8.44
#   epoch=  36, mse_train=6.76, mse_val=8.35
#   epoch=  37, mse_train=6.67, mse_val=8.26
#   epoch=  38, mse_train=6.58, mse_val=8.18
#   epoch=  39, mse_train=6.50, mse_val=8.09
#   epoch=  40, mse_train=6.41, mse_val=8.01
#   epoch=  41, mse_train=6.33, mse_val=7.92
#   epoch=  42, mse_train=6.25, mse_val=7.84
#   epoch=  43, mse_train=6.17, mse_val=7.76
#   epoch=  44, mse_train=6.10, mse_val=7.68
#   epoch=  45, mse_train=6.02, mse_val=7.60
#   epoch=  46, mse_train=5.95, mse_val=7.52
#   epoch=  47, mse_train=5.87, mse_val=7.45
#   epoch=  48, mse_train=5.80, mse_val=7.37
#   epoch=  49, mse_train=5.73, mse_val=7.29
#   epoch=  50, mse_train=5.66, mse_val=7.22
#   epoch=  51, mse_train=5.59, mse_val=7.15
#   epoch=  52, mse_train=5.53, mse_val=7.08
#   epoch=  53, mse_train=5.46, mse_val=7.00
#   epoch=  54, mse_train=5.40, mse_val=6.93
#   epoch=  55, mse_train=5.33, mse_val=6.87
#   epoch=  56, mse_train=5.27, mse_val=6.80
#   epoch=  57, mse_train=5.21, mse_val=6.73
#   epoch=  58, mse_train=5.15, mse_val=6.66
#   epoch=  59, mse_train=5.09, mse_val=6.60
#   epoch=  60, mse_train=5.03, mse_val=6.53
#   epoch=  61, mse_train=4.97, mse_val=6.47
#   epoch=  62, mse_train=4.91, mse_val=6.41
#   epoch=  63, mse_train=4.86, mse_val=6.34
#   epoch=  64, mse_train=4.80, mse_val=6.28
#   epoch=  65, mse_train=4.75, mse_val=6.22
#   epoch=  66, mse_train=4.70, mse_val=6.16
#   epoch=  67, mse_train=4.64, mse_val=6.10
#   epoch=  68, mse_train=4.59, mse_val=6.04
#   epoch=  69, mse_train=4.54, mse_val=5.99
#   epoch=  70, mse_train=4.49, mse_val=5.93
#   epoch=  71, mse_train=4.44, mse_val=5.87
#   epoch=  72, mse_train=4.39, mse_val=5.82
#   epoch=  73, mse_train=4.34, mse_val=5.76
#   epoch=  74, mse_train=4.30, mse_val=5.71
#   epoch=  75, mse_train=4.25, mse_val=5.66
#   epoch=  76, mse_train=4.20, mse_val=5.60
#   epoch=  77, mse_train=4.16, mse_val=5.55
#   epoch=  78, mse_train=4.11, mse_val=5.50
#   epoch=  79, mse_train=4.07, mse_val=5.45
#   epoch=  80, mse_train=4.03, mse_val=5.40
#   epoch=  81, mse_train=3.98, mse_val=5.35
#   epoch=  82, mse_train=3.94, mse_val=5.30
#   epoch=  83, mse_train=3.90, mse_val=5.25
#   epoch=  84, mse_train=3.86, mse_val=5.21
#   epoch=  85, mse_train=3.82, mse_val=5.16
#   epoch=  86, mse_train=3.78, mse_val=5.11
#   epoch=  87, mse_train=3.74, mse_val=5.07
#   epoch=  88, mse_train=3.70, mse_val=5.02
#   epoch=  89, mse_train=3.66, mse_val=4.98
#   epoch=  90, mse_train=3.63, mse_val=4.93
#   epoch=  91, mse_train=3.59, mse_val=4.89
#   epoch=  92, mse_train=3.55, mse_val=4.84
#   epoch=  93, mse_train=3.52, mse_val=4.80
#   epoch=  94, mse_train=3.48, mse_val=4.76
#   epoch=  95, mse_train=3.44, mse_val=4.72
#   epoch=  96, mse_train=3.41, mse_val=4.68
#   epoch=  97, mse_train=3.38, mse_val=4.64
#   epoch=  98, mse_train=3.34, mse_val=4.60
#   epoch=  99, mse_train=3.31, mse_val=4.56
#   epoch= 100, mse_train=3.28, mse_val=4.52
#   epoch= 101, mse_train=3.24, mse_val=4.48
#   epoch= 102, mse_train=3.21, mse_val=4.44
#   epoch= 103, mse_train=3.18, mse_val=4.40
#   epoch= 104, mse_train=3.15, mse_val=4.37
#   epoch= 105, mse_train=3.12, mse_val=4.33
#   epoch= 106, mse_train=3.09, mse_val=4.29
#   epoch= 107, mse_train=3.06, mse_val=4.26
#   epoch= 108, mse_train=3.03, mse_val=4.22
#   epoch= 109, mse_train=3.00, mse_val=4.19
#   epoch= 110, mse_train=2.97, mse_val=4.15
#   epoch= 111, mse_train=2.94, mse_val=4.12
#   epoch= 112, mse_train=2.92, mse_val=4.08
#   epoch= 113, mse_train=2.89, mse_val=4.05
#   epoch= 114, mse_train=2.86, mse_val=4.02
#   epoch= 115, mse_train=2.83, mse_val=3.98
#   epoch= 116, mse_train=2.81, mse_val=3.95
#   epoch= 117, mse_train=2.78, mse_val=3.92
#   epoch= 118, mse_train=2.76, mse_val=3.89
#   epoch= 119, mse_train=2.73, mse_val=3.86
#   epoch= 120, mse_train=2.71, mse_val=3.83
#   epoch= 121, mse_train=2.68, mse_val=3.80
#   epoch= 122, mse_train=2.66, mse_val=3.77
#   epoch= 123, mse_train=2.63, mse_val=3.74
#   epoch= 124, mse_train=2.61, mse_val=3.71
#   epoch= 125, mse_train=2.59, mse_val=3.68
#   epoch= 126, mse_train=2.56, mse_val=3.65
#   epoch= 127, mse_train=2.54, mse_val=3.62
#   epoch= 128, mse_train=2.52, mse_val=3.59
#   epoch= 129, mse_train=2.50, mse_val=3.56
#   epoch= 130, mse_train=2.47, mse_val=3.54
#   epoch= 131, mse_train=2.45, mse_val=3.51
#   epoch= 132, mse_train=2.43, mse_val=3.48
#   epoch= 133, mse_train=2.41, mse_val=3.46
#   epoch= 134, mse_train=2.39, mse_val=3.43
#   epoch= 135, mse_train=2.37, mse_val=3.41
#   epoch= 136, mse_train=2.35, mse_val=3.38
#   epoch= 137, mse_train=2.33, mse_val=3.35
#   epoch= 138, mse_train=2.31, mse_val=3.33
#   epoch= 139, mse_train=2.29, mse_val=3.30
#   epoch= 140, mse_train=2.27, mse_val=3.28
#   epoch= 141, mse_train=2.25, mse_val=3.26
#   epoch= 142, mse_train=2.23, mse_val=3.23
#   epoch= 143, mse_train=2.21, mse_val=3.21
#   epoch= 144, mse_train=2.20, mse_val=3.19
#   epoch= 145, mse_train=2.18, mse_val=3.16
#   epoch= 146, mse_train=2.16, mse_val=3.14
#   epoch= 147, mse_train=2.14, mse_val=3.12
#   epoch= 148, mse_train=2.12, mse_val=3.10
#   epoch= 149, mse_train=2.11, mse_val=3.07
#   epoch= 150, mse_train=2.09, mse_val=3.05
#   epoch= 151, mse_train=2.07, mse_val=3.03
#   epoch= 152, mse_train=2.06, mse_val=3.01
#   epoch= 153, mse_train=2.04, mse_val=2.99
#   epoch= 154, mse_train=2.02, mse_val=2.97
#   epoch= 155, mse_train=2.01, mse_val=2.95
#   epoch= 156, mse_train=1.99, mse_val=2.93
#   epoch= 157, mse_train=1.98, mse_val=2.91
#   epoch= 158, mse_train=1.96, mse_val=2.89
#   epoch= 159, mse_train=1.95, mse_val=2.87
#   epoch= 160, mse_train=1.93, mse_val=2.85
#   epoch= 161, mse_train=1.92, mse_val=2.83
#   epoch= 162, mse_train=1.90, mse_val=2.81
#   epoch= 163, mse_train=1.89, mse_val=2.79
#   epoch= 164, mse_train=1.87, mse_val=2.77
#   epoch= 165, mse_train=1.86, mse_val=2.75
#   epoch= 166, mse_train=1.85, mse_val=2.74
#   epoch= 167, mse_train=1.83, mse_val=2.72
#   epoch= 168, mse_train=1.82, mse_val=2.70
#   epoch= 169, mse_train=1.81, mse_val=2.68
#   epoch= 170, mse_train=1.79, mse_val=2.67
#   epoch= 171, mse_train=1.78, mse_val=2.65
#   epoch= 172, mse_train=1.77, mse_val=2.63
#   epoch= 173, mse_train=1.76, mse_val=2.62
#   epoch= 174, mse_train=1.74, mse_val=2.60
#   epoch= 175, mse_train=1.73, mse_val=2.58
#   epoch= 176, mse_train=1.72, mse_val=2.57
#   epoch= 177, mse_train=1.71, mse_val=2.55
#   epoch= 178, mse_train=1.69, mse_val=2.54
#   epoch= 179, mse_train=1.68, mse_val=2.52
#   epoch= 180, mse_train=1.67, mse_val=2.50
#   epoch= 181, mse_train=1.66, mse_val=2.49
#   epoch= 182, mse_train=1.65, mse_val=2.47
#   epoch= 183, mse_train=1.64, mse_val=2.46
#   epoch= 184, mse_train=1.63, mse_val=2.45
#   epoch= 185, mse_train=1.62, mse_val=2.43
#   epoch= 186, mse_train=1.60, mse_val=2.42
#   epoch= 187, mse_train=1.59, mse_val=2.40
#   epoch= 188, mse_train=1.58, mse_val=2.39
#   epoch= 189, mse_train=1.57, mse_val=2.37
#   epoch= 190, mse_train=1.56, mse_val=2.36
#   epoch= 191, mse_train=1.55, mse_val=2.35
#   epoch= 192, mse_train=1.54, mse_val=2.33
#   epoch= 193, mse_train=1.53, mse_val=2.32
#   epoch= 194, mse_train=1.52, mse_val=2.31
#   epoch= 195, mse_train=1.51, mse_val=2.29
#   epoch= 196, mse_train=1.50, mse_val=2.28
#   epoch= 197, mse_train=1.49, mse_val=2.27
#   epoch= 198, mse_train=1.49, mse_val=2.26
#   epoch= 199, mse_train=1.48, mse_val=2.24
#   epoch= 200, mse_train=1.47, mse_val=2.23
#   epoch= 201, mse_train=1.46, mse_val=2.22
#   epoch= 202, mse_train=1.45, mse_val=2.21
#   epoch= 203, mse_train=1.44, mse_val=2.20
#   epoch= 204, mse_train=1.43, mse_val=2.19
#   epoch= 205, mse_train=1.42, mse_val=2.17
#   epoch= 206, mse_train=1.42, mse_val=2.16
#   epoch= 207, mse_train=1.41, mse_val=2.15
#   epoch= 208, mse_train=1.40, mse_val=2.14
#   epoch= 209, mse_train=1.39, mse_val=2.13
#   epoch= 210, mse_train=1.38, mse_val=2.12
#   epoch= 211, mse_train=1.37, mse_val=2.11
#   epoch= 212, mse_train=1.37, mse_val=2.10
#   epoch= 213, mse_train=1.36, mse_val=2.09
#   epoch= 214, mse_train=1.35, mse_val=2.08
#   epoch= 215, mse_train=1.34, mse_val=2.07
#   epoch= 216, mse_train=1.34, mse_val=2.06
#   epoch= 217, mse_train=1.33, mse_val=2.05
#   epoch= 218, mse_train=1.32, mse_val=2.04
#   epoch= 219, mse_train=1.31, mse_val=2.03
#   epoch= 220, mse_train=1.31, mse_val=2.02
#   epoch= 221, mse_train=1.30, mse_val=2.01
#   epoch= 222, mse_train=1.29, mse_val=2.00
#   epoch= 223, mse_train=1.29, mse_val=1.99
#   epoch= 224, mse_train=1.28, mse_val=1.98
#   epoch= 225, mse_train=1.27, mse_val=1.97
#   epoch= 226, mse_train=1.27, mse_val=1.96
#   epoch= 227, mse_train=1.26, mse_val=1.95
#   epoch= 228, mse_train=1.25, mse_val=1.94
#   epoch= 229, mse_train=1.25, mse_val=1.94
#   epoch= 230, mse_train=1.24, mse_val=1.93
#   epoch= 231, mse_train=1.23, mse_val=1.92
#   epoch= 232, mse_train=1.23, mse_val=1.91
#   epoch= 233, mse_train=1.22, mse_val=1.90
#   epoch= 234, mse_train=1.22, mse_val=1.89
#   epoch= 235, mse_train=1.21, mse_val=1.89
#   epoch= 236, mse_train=1.20, mse_val=1.88
#   epoch= 237, mse_train=1.20, mse_val=1.87
#   epoch= 238, mse_train=1.19, mse_val=1.86
#   epoch= 239, mse_train=1.19, mse_val=1.85
#   epoch= 240, mse_train=1.18, mse_val=1.85
#   epoch= 241, mse_train=1.18, mse_val=1.84
#   epoch= 242, mse_train=1.17, mse_val=1.83
#   epoch= 243, mse_train=1.16, mse_val=1.82
#   epoch= 244, mse_train=1.16, mse_val=1.82
#   epoch= 245, mse_train=1.15, mse_val=1.81
#   epoch= 246, mse_train=1.15, mse_val=1.80
#   epoch= 247, mse_train=1.14, mse_val=1.80
#   epoch= 248, mse_train=1.14, mse_val=1.79
#   epoch= 249, mse_train=1.13, mse_val=1.78
#   epoch= 250, mse_train=1.13, mse_val=1.78
#   epoch= 251, mse_train=1.12, mse_val=1.77
#   epoch= 252, mse_train=1.12, mse_val=1.76
#   epoch= 253, mse_train=1.11, mse_val=1.76
#   epoch= 254, mse_train=1.11, mse_val=1.75
#   epoch= 255, mse_train=1.10, mse_val=1.74
#   epoch= 256, mse_train=1.10, mse_val=1.74
#   epoch= 257, mse_train=1.09, mse_val=1.73
#   epoch= 258, mse_train=1.09, mse_val=1.73
#   epoch= 259, mse_train=1.08, mse_val=1.72
#   epoch= 260, mse_train=1.08, mse_val=1.71
#   epoch= 261, mse_train=1.08, mse_val=1.71
#   epoch= 262, mse_train=1.07, mse_val=1.70
#   epoch= 263, mse_train=1.07, mse_val=1.70
#   epoch= 264, mse_train=1.06, mse_val=1.69
#   epoch= 265, mse_train=1.06, mse_val=1.69
#   epoch= 266, mse_train=1.05, mse_val=1.68
#   epoch= 267, mse_train=1.05, mse_val=1.67
#   epoch= 268, mse_train=1.05, mse_val=1.67
#   epoch= 269, mse_train=1.04, mse_val=1.66
#   epoch= 270, mse_train=1.04, mse_val=1.66
#   epoch= 271, mse_train=1.03, mse_val=1.65
#   epoch= 272, mse_train=1.03, mse_val=1.65
#   epoch= 273, mse_train=1.03, mse_val=1.64
#   epoch= 274, mse_train=1.02, mse_val=1.64
#   epoch= 275, mse_train=1.02, mse_val=1.63
#   epoch= 276, mse_train=1.01, mse_val=1.63
#   epoch= 277, mse_train=1.01, mse_val=1.62
#   epoch= 278, mse_train=1.01, mse_val=1.62
#   epoch= 279, mse_train=1.00, mse_val=1.62
#   epoch= 280, mse_train=1.00, mse_val=1.61
#   epoch= 281, mse_train=1.00, mse_val=1.61
#   epoch= 282, mse_train=0.99, mse_val=1.60
#   epoch= 283, mse_train=0.99, mse_val=1.60
#   epoch= 284, mse_train=0.98, mse_val=1.59
#   epoch= 285, mse_train=0.98, mse_val=1.59
#   epoch= 286, mse_train=0.98, mse_val=1.58
#   epoch= 287, mse_train=0.97, mse_val=1.58
#   epoch= 288, mse_train=0.97, mse_val=1.58
#   epoch= 289, mse_train=0.97, mse_val=1.57
#   epoch= 290, mse_train=0.96, mse_val=1.57
#   epoch= 291, mse_train=0.96, mse_val=1.56
#   epoch= 292, mse_train=0.96, mse_val=1.56
#   epoch= 293, mse_train=0.95, mse_val=1.56
#   epoch= 294, mse_train=0.95, mse_val=1.55
#   epoch= 295, mse_train=0.95, mse_val=1.55
#   epoch= 296, mse_train=0.95, mse_val=1.55
#   epoch= 297, mse_train=0.94, mse_val=1.54
#   epoch= 298, mse_train=0.94, mse_val=1.54
#   epoch= 299, mse_train=0.94, mse_val=1.54
#   epoch= 300, mse_train=0.93, mse_val=1.53
#   epoch= 301, mse_train=0.93, mse_val=1.53
#   epoch= 302, mse_train=0.93, mse_val=1.53
#   epoch= 303, mse_train=0.92, mse_val=1.52
#   epoch= 304, mse_train=0.92, mse_val=1.52
#   epoch= 305, mse_train=0.92, mse_val=1.52
#   epoch= 306, mse_train=0.92, mse_val=1.51
#   epoch= 307, mse_train=0.91, mse_val=1.51
#   epoch= 308, mse_train=0.91, mse_val=1.51
#   epoch= 309, mse_train=0.91, mse_val=1.50
#   epoch= 310, mse_train=0.91, mse_val=1.50
#   epoch= 311, mse_train=0.90, mse_val=1.50
#   epoch= 312, mse_train=0.90, mse_val=1.50
#   epoch= 313, mse_train=0.90, mse_val=1.49
#   epoch= 314, mse_train=0.89, mse_val=1.49
#   epoch= 315, mse_train=0.89, mse_val=1.49
#   epoch= 316, mse_train=0.89, mse_val=1.48
#   epoch= 317, mse_train=0.89, mse_val=1.48
#   epoch= 318, mse_train=0.88, mse_val=1.48
#   epoch= 319, mse_train=0.88, mse_val=1.48
#   epoch= 320, mse_train=0.88, mse_val=1.47
#   epoch= 321, mse_train=0.88, mse_val=1.47
#   epoch= 322, mse_train=0.87, mse_val=1.47
#   epoch= 323, mse_train=0.87, mse_val=1.47
#   epoch= 324, mse_train=0.87, mse_val=1.46
#   epoch= 325, mse_train=0.87, mse_val=1.46
#   epoch= 326, mse_train=0.87, mse_val=1.46
#   epoch= 327, mse_train=0.86, mse_val=1.46
#   epoch= 328, mse_train=0.86, mse_val=1.46
#   epoch= 329, mse_train=0.86, mse_val=1.45
#   epoch= 330, mse_train=0.86, mse_val=1.45
#   epoch= 331, mse_train=0.85, mse_val=1.45
#   epoch= 332, mse_train=0.85, mse_val=1.45
#   epoch= 333, mse_train=0.85, mse_val=1.45
#   epoch= 334, mse_train=0.85, mse_val=1.44
#   epoch= 335, mse_train=0.85, mse_val=1.44
#   epoch= 336, mse_train=0.84, mse_val=1.44
#   epoch= 337, mse_train=0.84, mse_val=1.44
#   epoch= 338, mse_train=0.84, mse_val=1.44
#   epoch= 339, mse_train=0.84, mse_val=1.44
#   epoch= 340, mse_train=0.84, mse_val=1.43
#   epoch= 341, mse_train=0.83, mse_val=1.43
#   epoch= 342, mse_train=0.83, mse_val=1.43
#   epoch= 343, mse_train=0.83, mse_val=1.43
#   epoch= 344, mse_train=0.83, mse_val=1.43
#   epoch= 345, mse_train=0.83, mse_val=1.43
#   epoch= 346, mse_train=0.82, mse_val=1.42
#   epoch= 347, mse_train=0.82, mse_val=1.42
#   epoch= 348, mse_train=0.82, mse_val=1.42
#   epoch= 349, mse_train=0.82, mse_val=1.42
#   epoch= 350, mse_train=0.82, mse_val=1.42
#   epoch= 351, mse_train=0.81, mse_val=1.42
#   epoch= 352, mse_train=0.81, mse_val=1.42
#   epoch= 353, mse_train=0.81, mse_val=1.41
#   epoch= 354, mse_train=0.81, mse_val=1.41
#   epoch= 355, mse_train=0.81, mse_val=1.41
#   epoch= 356, mse_train=0.80, mse_val=1.41
#   epoch= 357, mse_train=0.80, mse_val=1.41
#   epoch= 358, mse_train=0.80, mse_val=1.41
#   epoch= 359, mse_train=0.80, mse_val=1.41
#   epoch= 360, mse_train=0.80, mse_val=1.41
#   epoch= 361, mse_train=0.80, mse_val=1.41
#   epoch= 362, mse_train=0.79, mse_val=1.41
#   epoch= 363, mse_train=0.79, mse_val=1.40
#   epoch= 364, mse_train=0.79, mse_val=1.40
#   epoch= 365, mse_train=0.79, mse_val=1.40
#   epoch= 366, mse_train=0.79, mse_val=1.40
#   epoch= 367, mse_train=0.79, mse_val=1.40
#   epoch= 368, mse_train=0.78, mse_val=1.40
#   epoch= 369, mse_train=0.78, mse_val=1.40
#   epoch= 370, mse_train=0.78, mse_val=1.40
#   epoch= 371, mse_train=0.78, mse_val=1.40
#   epoch= 372, mse_train=0.78, mse_val=1.40
#   epoch= 373, mse_train=0.78, mse_val=1.40
#   epoch= 374, mse_train=0.78, mse_val=1.40
#   epoch= 375, mse_train=0.77, mse_val=1.40
#   epoch= 376, mse_train=0.77, mse_val=1.40
#   epoch= 377, mse_train=0.77, mse_val=1.39
#   epoch= 378, mse_train=0.77, mse_val=1.39
#   epoch= 379, mse_train=0.77, mse_val=1.39
#   epoch= 380, mse_train=0.77, mse_val=1.39
#   epoch= 381, mse_train=0.77, mse_val=1.39
#   epoch= 382, mse_train=0.76, mse_val=1.39
#   epoch= 383, mse_train=0.76, mse_val=1.39
#   epoch= 384, mse_train=0.76, mse_val=1.39
#   epoch= 385, mse_train=0.76, mse_val=1.39
#   epoch= 386, mse_train=0.76, mse_val=1.39
#   epoch= 387, mse_train=0.76, mse_val=1.39
#   epoch= 388, mse_train=0.76, mse_val=1.39
#   epoch= 389, mse_train=0.75, mse_val=1.39
#   epoch= 390, mse_train=0.75, mse_val=1.39
#   epoch= 391, mse_train=0.75, mse_val=1.39
#   epoch= 392, mse_train=0.75, mse_val=1.39
#   epoch= 393, mse_train=0.75, mse_val=1.39
#   epoch= 394, mse_train=0.75, mse_val=1.39
#   epoch= 395, mse_train=0.75, mse_val=1.39
#   epoch= 396, mse_train=0.75, mse_val=1.39
#   epoch= 397, mse_train=0.74, mse_val=1.39
#   epoch= 398, mse_train=0.74, mse_val=1.39
#   epoch= 399, mse_train=0.74, mse_val=1.39
#   epoch= 400, mse_train=0.74, mse_val=1.39
#   epoch= 401, mse_train=0.74, mse_val=1.39
#   epoch= 402, mse_train=0.74, mse_val=1.39
#   epoch= 403, mse_train=0.74, mse_val=1.39
#   epoch= 404, mse_train=0.74, mse_val=1.39
#   epoch= 405, mse_train=0.73, mse_val=1.39
#   epoch= 406, mse_train=0.73, mse_val=1.39
#   epoch= 407, mse_train=0.73, mse_val=1.39
#   epoch= 408, mse_train=0.73, mse_val=1.39
#   epoch= 409, mse_train=0.73, mse_val=1.39
#   epoch= 410, mse_train=0.73, mse_val=1.39
#   epoch= 411, mse_train=0.73, mse_val=1.39
#   epoch= 412, mse_train=0.73, mse_val=1.39
#   epoch= 413, mse_train=0.72, mse_val=1.39
#   epoch= 414, mse_train=0.72, mse_val=1.39
#   epoch= 415, mse_train=0.72, mse_val=1.39
#   epoch= 416, mse_train=0.72, mse_val=1.39
#   epoch= 417, mse_train=0.72, mse_val=1.39
#   epoch= 418, mse_train=0.72, mse_val=1.39
#   epoch= 419, mse_train=0.72, mse_val=1.40
#   epoch= 420, mse_train=0.72, mse_val=1.40
#   epoch= 421, mse_train=0.72, mse_val=1.40
#   epoch= 422, mse_train=0.72, mse_val=1.40
#   epoch= 423, mse_train=0.71, mse_val=1.40
#   epoch= 424, mse_train=0.71, mse_val=1.40
#   epoch= 425, mse_train=0.71, mse_val=1.40
#   epoch= 426, mse_train=0.71, mse_val=1.40
#   epoch= 427, mse_train=0.71, mse_val=1.40
#   epoch= 428, mse_train=0.71, mse_val=1.40
#   epoch= 429, mse_train=0.71, mse_val=1.40
#   epoch= 430, mse_train=0.71, mse_val=1.40
#   epoch= 431, mse_train=0.71, mse_val=1.40
#   epoch= 432, mse_train=0.71, mse_val=1.40
#   epoch= 433, mse_train=0.70, mse_val=1.40
#   epoch= 434, mse_train=0.70, mse_val=1.40
#   epoch= 435, mse_train=0.70, mse_val=1.41
#   epoch= 436, mse_train=0.70, mse_val=1.41
#   epoch= 437, mse_train=0.70, mse_val=1.41
#   epoch= 438, mse_train=0.70, mse_val=1.41
#   epoch= 439, mse_train=0.70, mse_val=1.41
#   epoch= 440, mse_train=0.70, mse_val=1.41
#   epoch= 441, mse_train=0.70, mse_val=1.41
#   epoch= 442, mse_train=0.70, mse_val=1.41
#   epoch= 443, mse_train=0.69, mse_val=1.41
#   epoch= 444, mse_train=0.69, mse_val=1.41
#   epoch= 445, mse_train=0.69, mse_val=1.41
#   epoch= 446, mse_train=0.69, mse_val=1.41
#   epoch= 447, mse_train=0.69, mse_val=1.42
#   epoch= 448, mse_train=0.69, mse_val=1.42
#   epoch= 449, mse_train=0.69, mse_val=1.42
#   epoch= 450, mse_train=0.69, mse_val=1.42
#   epoch= 451, mse_train=0.69, mse_val=1.42
#   epoch= 452, mse_train=0.69, mse_val=1.42
#   epoch= 453, mse_train=0.69, mse_val=1.42
#   epoch= 454, mse_train=0.69, mse_val=1.42
#   epoch= 455, mse_train=0.68, mse_val=1.42
#   epoch= 456, mse_train=0.68, mse_val=1.43
#   epoch= 457, mse_train=0.68, mse_val=1.43
#   epoch= 458, mse_train=0.68, mse_val=1.43
#   epoch= 459, mse_train=0.68, mse_val=1.43
#   epoch= 460, mse_train=0.68, mse_val=1.43
#   epoch= 461, mse_train=0.68, mse_val=1.43
#   epoch= 462, mse_train=0.68, mse_val=1.43
#   epoch= 463, mse_train=0.68, mse_val=1.43
#   epoch= 464, mse_train=0.68, mse_val=1.43
#   epoch= 465, mse_train=0.68, mse_val=1.44
#   epoch= 466, mse_train=0.68, mse_val=1.44
#   epoch= 467, mse_train=0.67, mse_val=1.44
#   epoch= 468, mse_train=0.67, mse_val=1.44
#   epoch= 469, mse_train=0.67, mse_val=1.44
#   epoch= 470, mse_train=0.67, mse_val=1.44
#   epoch= 471, mse_train=0.67, mse_val=1.44
#   epoch= 472, mse_train=0.67, mse_val=1.45
#   epoch= 473, mse_train=0.67, mse_val=1.45
#   epoch= 474, mse_train=0.67, mse_val=1.45
#   epoch= 475, mse_train=0.67, mse_val=1.45
#   epoch= 476, mse_train=0.67, mse_val=1.45
#   epoch= 477, mse_train=0.67, mse_val=1.45
#   epoch= 478, mse_train=0.67, mse_val=1.45
#   epoch= 479, mse_train=0.67, mse_val=1.45
#   epoch= 480, mse_train=0.66, mse_val=1.46
#   epoch= 481, mse_train=0.66, mse_val=1.46
#   epoch= 482, mse_train=0.66, mse_val=1.46
#   epoch= 483, mse_train=0.66, mse_val=1.46
#   epoch= 484, mse_train=0.66, mse_val=1.46
#   epoch= 485, mse_train=0.66, mse_val=1.46
#   epoch= 486, mse_train=0.66, mse_val=1.47
#   epoch= 487, mse_train=0.66, mse_val=1.47
#   epoch= 488, mse_train=0.66, mse_val=1.47
#   epoch= 489, mse_train=0.66, mse_val=1.47
#   epoch= 490, mse_train=0.66, mse_val=1.47
#   epoch= 491, mse_train=0.66, mse_val=1.47
#   epoch= 492, mse_train=0.66, mse_val=1.47
#   epoch= 493, mse_train=0.66, mse_val=1.48
#   epoch= 494, mse_train=0.66, mse_val=1.48
#   epoch= 495, mse_train=0.65, mse_val=1.48
#   epoch= 496, mse_train=0.65, mse_val=1.48
#   epoch= 497, mse_train=0.65, mse_val=1.48
#   epoch= 498, mse_train=0.65, mse_val=1.48
#   epoch= 499, mse_train=0.65, mse_val=1.49
# OK

# %%
# Run code: Qb(part III)

best_epoch = np.argmin(val_errors)
best_val_rmse = np.sqrt(val_errors[best_epoch])

plt.figure(figsize=(10,5))
plt.annotate('Best model',
             xy=(best_epoch, best_val_rmse),
             xytext=(best_epoch, best_val_rmse + 1),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=16,
            )

best_val_rmse -= 0.03  # just to make the graph look better
plt.plot([0, n_epochs], [best_val_rmse, best_val_rmse], "k:", linewidth=2)
plt.plot(np.sqrt(train_errors), "b--", linewidth=2, label="Training set")
plt.plot(np.sqrt(val_errors), "g-", linewidth=3, label="Validation set")
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("RMSE", fontsize=14)
plt.show()

# %% [markdown]
# ANSWER:
# Antallet af epochs er antallet af gange SGDRegressor bliver kørt, da den i koden over er sat til at have en Warm Start så tager den forrige ændringer af væægtene med i træningen. Af den grund falder rmse for hver gennemkørsel for træningsdataet. For test dataet er det lidt anderledes, da validation dattaets rmse stiger efter et hvos antal epochers stiger. Dette er igen på grundd af at modellen begynder at overfitte, hvilket skyldes SGDRegressorens måde at vælge gradienten på. Den vælger en instans for hver runde(ikke epoche), så den når ikke igennem alle instanser for hver epoche, og da max_iter er sat til 1, s[ er det kun en instant den vælger for hver epoche. Der kommer derfor et tidspunkt, hvor modellen efterhånden har taget for mange træningsinstanser med i betragtningen og modellen begynder at beskrive støjen.

# %% [markdown]
# ### [OPTIONAL] Qc  Early Stopping
#
# How would you implement ___early stopping___, in the code above?
#
# Try it out in the code, and write an explanation of the early stopping concept.

# %%
# TODO: Qc...

# %% [markdown]
# ### Qd Explain the Polynomial RMSE-Capacity plot
#
# Now we revisit the concepts from `capacity_under_overfitting.ipynb` notebook and the polynomial fitting with a given capacity (polynomial degree).
#
# Peek into the cell below, and explain the generated RMSE-Capacity plot. Why does the _training error keep dropping_, while the _CV-error drops_ until around capacity 3, and then begin to rise again?
#
# What does the x-axis _Capacity_ and y-axis _RMSE_ represent?
#
# Try increasing the model capacity. What happens when you do plots for `degrees` larger than around 10?

# %%
# Run and review this code
# NOTE: modified code from [GITHOML], 04_training_linear_models.ipynb

# %matplotlib inline

from math import sqrt
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

def true_fun(X):
    return np.cos(1.5 * np.pi * X)

def GenerateData():
    n_samples = 30
    #degrees = [1, 4, 15]
    degrees = range(1,8)

    X = np.sort(np.random.rand(n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    return X, y, degrees

np.random.seed(0)
X, y, degrees  = GenerateData()

print("Iterating...degrees=",degrees)
capacities, rmses_training, rmses_cv= [], [], []
for i in range(len(degrees)):
    d=degrees[i]
    
    polynomial_features = PolynomialFeatures(degree=d, include_bias=False)
    
    linear_regression = LinearRegression()
    pipeline = Pipeline([
            ("polynomial_features", polynomial_features),
            ("linear_regression", linear_regression)
        ])
    
    Z = X[:, np.newaxis]
    pipeline.fit(Z, y)
    
    p = pipeline.predict(Z)
    train_rms = mean_squared_error(y,p)

    # Evaluate the models using crossvalidation
    scores = cross_val_score(pipeline, Z, y, scoring="neg_mean_squared_error", cv=10)
    score_mean = -scores.mean()
    
    rmse_training=sqrt(train_rms)
    rmse_cv=sqrt(score_mean)
    
    print(f"  degree={d:4d}, rmse_training={rmse_training:4.2f}, rmse_cv={rmse_cv:4.2f}")
    
    capacities    .append(d)
    rmses_training.append(rmse_training)
    rmses_cv      .append(rmse_cv)
    
plt.figure(figsize=(7,4))
plt.plot(capacities, rmses_training, "b--", linewidth=2, label="training RMSE")
plt.plot(capacities, rmses_cv, "g-", linewidth=2, label="CV RMSE")
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Capacity", fontsize=14)
plt.ylabel("RMSE", fontsize=14)
plt.show()

print('OK')
# Out:
# Iterating...degrees= range(1, 20)
#   degree=   1, rmse_training=0.48, rmse_cv=0.64
#   degree=   2, rmse_training=0.17, rmse_cv=0.24
#   degree=   3, rmse_training=0.11, rmse_cv=0.14
#   degree=   4, rmse_training=0.11, rmse_cv=0.21
#   degree=   5, rmse_training=0.10, rmse_cv=0.31
#   degree=   6, rmse_training=0.10, rmse_cv=0.34
#   degree=   7, rmse_training=0.10, rmse_cv=0.44
#   degree=   8, rmse_training=0.10, rmse_cv=0.60
#   degree=   9, rmse_training=0.10, rmse_cv=4.61
#   degree=  10, rmse_training=0.10, rmse_cv=38.94
#   degree=  11, rmse_training=0.10, rmse_cv=154.97
#   degree=  12, rmse_training=0.10, rmse_cv=45.52
#   degree=  13, rmse_training=0.10, rmse_cv=1150.25
#   degree=  14, rmse_training=0.09, rmse_cv=2741.63
#   degree=  15, rmse_training=0.07, rmse_cv=13520.93
#   degree=  16, rmse_training=0.07, rmse_cv=113073.06
#   degree=  17, rmse_training=0.07, rmse_cv=63212.63
#   degree=  18, rmse_training=0.07, rmse_cv=904090.32
#   degree=  19, rmse_training=0.07, rmse_cv=652615.32
# OK

# %%
# TODO: Qd...answer in text form
